# %% [markdown]
# # Unit 10: **Fundamentals of electrochemistry. Debye-Huckel theory. Redox reactions and electrochemical cells.**
#
# # 1. Theory
#
# [check here](https://www.chem.msu.ru/rus/teaching/eremin/welcome.html)
#
# ## 1.1 Terminology
#
# - **Electrolytes**: Substances that conduct electricity when dissolved in water, due to the presence of ions.
# - **Electrodes**: Interfaces where oxidation or reduction occurs.
# - **Electrochemical potential (μ̃)**: Sum of chemical potential and electrical potential contribution. Governs ion motion in an electric field.
# - **Conductivity (κ)**: Proportional to ion concentration and mobility.
# - **Electrochemical equilibrium**: Established when the electrochemical potentials of species are balanced across an interface.
#
# ## 1.2 Debye–Hückel Theory
#
# Describes how electrostatic interactions affect ion behavior in dilute solutions.
#
# - **Key idea**: Each ion is surrounded by an “ionic atmosphere” of opposite charge, which reduces its effective activity.
# - **Activity coefficient (γ)**: Corrects concentrations to account for non-ideal ionic interactions.
# - **Debye–Hückel limiting law** (valid at low ionic strength *I*):
#
# ### A. Ionic strength
#
# The **ionic strength** (*I*) of a solution is a measure of the total concentration of ions, weighted by the square of their charges.
#
# **Formula:**
# $$
# I = \tfrac{1}{2} \sum_{i} m_i z_i^2
# $$
#
# where:
# - $m_i$ = molality of ion *i* (mol·kg$^{-1}$)
# - $z_i$ = charge number of ion *i*
# - The factor $\tfrac{1}{2}$ prevents double counting of ion–ion interactions.
#
# ### B. Computing activity coefficients
#
# $$
# \lg \gamma_\pm = -A z^2 \sqrt{I}
# $$
#
# species-resolved:
# **Debye–Hückel law:**
# $$
# \lg \gamma_i = -A z_i^2 \sqrt{I}, if I<0.01
# $$
# **Davies law:**
# $$
# \lg \gamma_i = -A \frac{ z_i^2 \sqrt{I}}{1 + B \sqrt{I}} + C\ I, if I<0.1
# $$
#
# $$
# \boxed{ A = 0.5\\ B = 1.0\\ C = 0.1}
# $$
#
# where:
# - *lg* - base-10 logarithm
# - *γ±* = mean activity coefficient
# - *z* = ion charge
# - *I* = ionic strength
# - *A* = constant depending on temperature and solvent dielectric constant
# - **Consequence**: Ionic solutions deviate from ideality even at low concentrations due to long-range Coulomb interactions.
#
#
# ### C. More Accurate Expression for A
# In general:
#
# $$
# A = \frac{1}{3} \left( \frac{2 \pi N_A \rho}{1000} \right)^{1/2} \cdot \frac{e^3}{(8 \pi \varepsilon_0 \varepsilon_r k_B T)^{3/2} \cdot 2.303 \, R T}
# $$
#
# where:
# - \($N_A$\) = Avogadro’s number
# - \($\rho$\) = solvent density (kg·L⁻¹)
# - \(e\) = elementary charge
# - \($\varepsilon_0$\) = permittivity of free space
# - \($\varepsilon_r$\) = dielectric constant of solvent
# - \($k_B$\) = Boltzmann constant
# - \(R\) = gas constant
# - \(T\) = absolute temperature
#
#
# In practice:
# For **aqueous solutions at 25 °C**:
#
# $$
# A \approx 0.509 \; \text{(mol/L)}^{-1/2}
# $$
#
# - At 18 °C, \($A \approx 0.488$\)
# - At 100 °C, \($A \approx 0.73$\)
#
#
#
# ## 1.3 Oxidation and Reduction
#
# - **Redox reactions**: Chemical processes involving electron transfer.
#   - **Oxidation** = loss of electrons
#   - **Reduction** = gain of electrons
# - Always occur in pairs (oxidation + reduction).
#
# ### A. Oxidation
# - **Definition**: The process of **loss of electrons** by a species.
# - General form:
#
# $$
# \text{M} \;\;\rightarrow\;\; \text{M}^{n+} + n e^-
# $$
#
# - Example (Zinc in Daniell cell):
#
# $$
# \text{Zn} \;\;\rightarrow\;\; \text{Zn}^{2+} + 2 e^-
# $$
#
#
# ### B. Reduction
# - **Definition**: The process of **gain of electrons** by a species.
# - General form:
#
# $$
# \text{X}^{n+} + n e^- \;\;\rightarrow\;\; \text{X}
# $$
#
# - Example (Copper in Daniell cell):
#
# $$
# \text{Cu}^{2+} + 2 e^- \;\;\rightarrow\;\; \text{Cu}
# $$
#
#
# ## 1.4 Electrochemical Cells
#
# ### A. Electrochemical Cells
#
# 1. **Galvanic (Voltaic) cells**
#    - Spontaneous redox reactions produce electricity ($\Delta G_{cell} < 0.0$ or $E_{cell} > 0.0$)
#    - Example: Daniell cell (Zn | Zn²⁺ || Cu²⁺ | Cu).
#
# 2. **Electrolytic cells**
#    - External electrical energy drives non-spontaneous reactions. ($\Delta G_{cell} > 0.0$ or $E_{cell} < 0.0$)
#    - Example: Electrolysis of water.
#
# ### B. Electrodes
#
# - **Definition**: Electrodes are conductive materials (usually metals or carbon) that provide a surface for electron transfer in an electrochemical cell.
# - Two types in a cell:
#   - **Anode** → where **oxidation** occurs (electrons leave the system)
#   - **Cathode** → where **reduction** occurs (electrons enter the system)
#
# 👉 Mnemonic: **"A" in Anode and "O" in Oxidation - vovels; "C" in Cathode and "R" in Reduction - consonants**
#
# ### C. Cell Reaction
#
# <img src="pics/Slide3.PNG" width="50%">
#
# ### C. Cell Potential and Nernst Equation
#
# - **Standard electrode potential (E°)**: Measure of a half-reaction’s tendency to be reduced.
# - **Cell potential, $E_{cell}$**:
#
# For the reduction process
# $$
# 𝐴 + n 𝑒^{−} → 𝐵
# $$
#
# the relationship between Gibbs free energy change and the corresponding potential is:
#
# $$
# \Delta_r G = -n F E_{cell}
# $$
#
# $$
# E_{\text{cell}} = E^\circ_{\text{cathode}} - E^\circ_{\text{anode}}
# $$
#
# - **Nernst equation** (accounts for non-standard conditions):
#
# $$
# E = E^\circ - \frac{RT}{nF} \ln Q
# $$
#
# where:
# - *n* = number of electrons transferred
# - *$F = 96485\ C\cdot mol^{-1}$* = Faraday constant
# - *Q* = reaction quotient

# %%
R = 8.314
T = 25 + 273.15 # 25 Celsius
F = 96485.0

print(F"RT/F = {R*T*1000/F:.2f} mV")
# Out:
# RT/F = 25.69 mV

# %% [markdown]
# [Database of standard redox potentials](https://www.chem.msu.ru/rus/handbook/redox/welcome.html)
#
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 2. Examples

# %% [markdown]
# ## Example 1 (computing ionic strengths)
#
# Compute ionic strength in the following solutions:
#
# a) NaCl solution (0.10 M NaCl)
# b) CaCl₂ solution (0.10 M CaCl₂)
# c) Mixture of NaCl (0.05 M) and MgSO₄ (0.10 M)
#
# ### Solution
#
# a) NaCl solution (0.10 M NaCl)
#
# - NaCl → Na⁺ (0.10 M, charge +1), Cl⁻ (0.10 M, charge –1)
#
# $$
# I = \tfrac{1}{2} \Big[ (0.10)(+1)^2 + (0.10)(-1)^2 \Big]
# $$
#
# $$
# = \tfrac{1}{2} (0.10 + 0.10) = 0.10 \;\text{M}
# $$
#
#
# b) CaCl₂ solution (0.10 M CaCl₂)
#
# - CaCl₂ → Ca²⁺ (0.10 M, charge +2), Cl⁻ (0.20 M, charge –1)
#
# $$
# I = \tfrac{1}{2} \Big[ (0.10)(+2)^2 + (0.20)(-1)^2 \Big]
# $$
#
# $$
# = \tfrac{1}{2} (0.40 + 0.20) = 0.30 \;\text{M}
# $$
#
#
# c) Mixture of NaCl (0.05 M) and MgSO₄ (0.10 M)
#
# - NaCl → Na⁺ (0.05 M, +1), Cl⁻ (0.05 M, –1)
# - MgSO₄ → Mg²⁺ (0.10 M, +2), SO₄²⁻ (0.10 M, –2)
#
# $$
# I = \tfrac{1}{2} \Big[ (0.05)(+1)^2 + (0.05)(-1)^2 + (0.10)(+2)^2 + (0.10)(-2)^2 \Big]
# $$
#
# $$
# = \tfrac{1}{2} (0.05 + 0.05 + 0.40 + 0.40) = \tfrac{1}{2} (0.90) = 0.45 \;\text{M}
# $$

# %% [markdown]
# ## Example 2 (Computing activity coefficients)
#
# Using the Debye-Huckel law, compute the activity coefficients of ions $K^+$, $Al^{3+}$ and $SO_4^{2-}$ in a $1.0 \times 10^{-3}$  M solution of $KAl(SO_4 )_2$ at 25 ℃.
#
# ### Solution

# %%
# It is useful to use some numpy:
import numpy as np

# Compute the molality of the solution: 1 L of water = 1 kg, so mol/L is numerically equal to mol/kg, so we can take 
# the molality of solution to be 1.0 * 10^-3 mol/kg
b_sol = 1e-3 # mol/kg

# Molalities of ions:
#                  K           Al        SO4
b = np.array( [ 1*b_sol,    1*b_sol,  2*b_sol])

# Charges of ions:
#              K+           Al3+      SO4^2- 
z = np.array([1,            3,       -2])

# Ionic strength:
I = 0.5 * np.sum( z*z * b)
print(I)

# Activity coefficients
A = 0.5

gamma  = 10 ** (-A*z*z*np.sqrt(I))
print(gamma)
# Out:
# 0.009000000000000001
# [0.89653208 0.37419029 0.64604585]

# %% [markdown]
# ## Example 3 (Computing Redox Potential)
#
# Compute the equilibrium constant of the disproportionation reaction $2Cu^+ ↔ Cu^{2+} + Cu(s)$ at 25 ℃. Use the tabulated date for standard redox potentials (V)
#
# ![image.png](attachment:image.png)
#
# ### Solution
#
# $Cu^+ + e^- -> Cu$   $E_1 = 0.521$ (R1)
#
# $Cu^{2+} + 2e^- -> Cu$  $E_2 = 0.337$  (R2)
#
# The $\Delta G$ for these reactions are:
#
# $\Delta G_1 = -1 F E_1$ (one electron process)
#
# $\Delta G_2 = -2 F E_1$ (two electron process)
#
# The total reaction:
#
# $2*(R1) - (R2) = 2Cu^+ + 2e^- + Cu -> Cu^{2+} + 2e^- + 2Cu <=>  2 Cu^+ -> Cu^{2+} + Cu$
#
# Hence:
#
# $\Delta G = 2\Delta G_1 - \Delta G_2$

# %%
F = 96485 # C/mol
R = 8.314
T = 25 + 273.15

E1 = 0.521 # V
E2 = 0.337 # V

dG1 = -1*F*E1
dG2 = -2*F*E2
dG = 2*dG1 - dG2 

print(F"dG = {dG} J/mol")

# Equilibrium constant:
lnK = -dG / (R * T)
K = np.exp(lnK)

print(F"K = {K}")
# Out:
# dG = -35506.48 J/mol
# K = 1662693.8697977632

# %% [markdown]
# # 3. Problems

# %% [markdown]
# ## 3.1.
#
# Compare the average molalities and ionic strength in: a) 1-1; b) 1-2; c) 1-3; and d) 2-2 electrolytes with the molality of m.

# %% [markdown]
# ## 3.2.
#
# Determine the activity coefficient of Ba2+ ions in a BaCl2 solution containing 0.001 moles of salt per 1 kg of water. The average activity coefficient of ions in a solution containing 0.003 moles of KCl per 1 kg of water is 0.94, and the the average activity coefficient of ions in BaCl2 solution containing 0.001 moles of salt per 1 kg of water is 0.88. Assume that the activity coefficient depends on the ionic strength and $\gamma_{K^+} = \gamma_{Cl^-}$

# %% [markdown]
# ## 3.3. [Eremin 11-17]
#
# The dissociation constant of acetic acit at 25 Celsius is $1.75 \times 10^{-5} mol \times L^{-1}$. Using the first approximation of the Debye-Huckel theory, calculate the degree of the acid dissociation if the acid molality is 0.100 mol/kg.

# %% [markdown]
# ## 3.4. [Eremin 12-1]
#
# Calculate the standard electrode potential of the $Fe^{3+}/Fe$ pair using data from the following table:
#
# | Pair     |  Reaction                 |   Value, V |
# | ---      | ---                       |  ---       |
# | Fe2+/Fe  | Fe2+ + 2e = Fe            |  -0.440    |
# | Fe3+,Fe2+/Pt |  Fe3+ + e = Fe2+      |  +0.771    |

# %% [markdown]
# ## 3.5.
#
# A galvanic cell is constructed with the following half-reactions:
#
#     Zn²⁺(aq) + 2e⁻ → Zn(s) ($E_1 = -0.76 V$)
#     Cu²⁺(aq) + 2e⁻ → Cu(s) ($E_2 = +0.34 V$)
#
# (a) Write the overall balanced reaction for the cell.
#
# (b) Calculate the standard cell potential (E°cell) for the galvanic cell.

# %% [markdown]
# ## 3.6.
#
# Consider a galvanic cell based on the following half-reactions:
#
#     Ag⁺(aq) + e⁻ → Ag(s) (E° = +0.80 V)
#     Zn²⁺(aq) + 2e⁻ → Zn(s) (E° = -0.76 V)
#
# The concentration of Ag⁺ is 0.010 M and the concentration of Zn²⁺ is 1.0 M.
#
# (a) Write the overall balanced cell reaction.
#
# (b) Calculate the cell potential (Ecell) at these conditions using the Nernst equation at 25°C.

# %% [markdown]
# ## 3.7.
#
# Given the following half-reactions:
#
#     Fe³⁺(aq) + e⁻ → Fe²⁺(aq) (E° = +0.77 V)
#     MnO₄⁻(aq) + 8H⁺(aq) + 5e⁻ → Mn²⁺(aq) + 4H₂O(l) (E° = +1.51 V)
#
# (a) Write the overall balanced reaction.
#
# (b) Calculate the standard cell potential (E°cell).
#
# (c) Determine the Gibbs free energy change (ΔG°) for the reaction at 25°C.

# %% [markdown]
# ## 3.8.
#
# A concentration cell consists of two half-cells containing Zn²⁺ solutions. In the first half-cell, [Zn²⁺] = 1.0 M, and in the second half-cell, [Zn²⁺] = 0.0010 M. Both electrodes are zinc.
#
# (a) Write the cell notation for this concentration cell.
#
# (b) Calculate the cell potential at 25°C using the Nernst equation.

# %% [markdown]
# ## 3.9.
#
# Consider the following reaction:
# $$
#     2H^+(aq)+2e^− → H_2(g)(E°=0.00 V)
# $$
#
# The hydrogen electrode is immersed in a solution where the pH is 4.00. The pressure of H₂ gas is 1.0 atm.
#
# (a) Calculate the cell potential at 25°C.
#
# (b) How would the cell potential change if the pH were 2.00 instead?

# %% [markdown]
# ## 3.10.
#
# Using the standard reduction potentials given below, predict whether the following reaction will be spontaneous under standard conditions:
#
#     2Al(s) + 3Cu2+(aq)→2Al3+(aq) + 3Cu(s)
#
# Reduction potentials:
#
#     Al³⁺ + 3e⁻ → Al(s) (E° = -1.66 V)
#     Cu²⁺ + 2e⁻ → Cu(s) (E° = +0.34 V)
#
# (a) Write the balanced reaction.
#
# (b) Calculate the standard cell potential (E°cell) and determine if the reaction is spontaneous.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Answers

# %% [markdown]
# ## 4.1.
#
# ## 4.2.
#
# ## 4.3.
#
# ## 4.4.
#
# ## 4.5.
# (b) $E°_{cell} = +1.10$ V
#
# ## 4.6.
# (b) $E_{cell} = 1.0864$ V
#
# ## 4.7.
# (b)  $E°_{cell} = 0.74$ V
#
# (c)  $ΔG°=−357.2\ kJ\cdot mol^{-1}$
#
# ## 4.8.
# (b)  $E_{cell} = 0.0888$ V
#
# ## 4.9.
# (a) E=−0.2368 V
# (b) E=−0.1184 V
#
# ## 4.10.
# $E°_{cell} = 2.00$ V

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
