# %% [markdown]
# # Unit 6: **Thermodynamic potentials. Fundamental equations of Thermodynamics. Maxwell’s equations.**
#
# # Significance
#
# * **Chemical reaction spontaneity**
# – Use of Gibbs free energy ($\Delta G$) to determine whether a reaction will proceed spontaneously under constant $T$ and $P$.
#
# * **Electrochemistry**
# – Relating Gibbs free energy to cell potentials ($\Delta G = -nFE$). Useful in designing batteries, sensors, and fuel cells.
#
# * **Phase equilibria**
# – Application of chemical potential to describe equilibrium between solid, liquid, and vapor phases.
#
# * **Adsorption and surface science**
# – Helmholtz free energy minimization applied to interfacial systems (e.g., catalyst surfaces).
#
# * **Material design**
# – Use of thermodynamic potentials to predict stability of new compounds, alloys, or nanomaterials.
#
# * **Spectroscopy and molecular thermodynamics**
# – Maxwell relations connect entropy, enthalpy, and measurable properties such as heat capacity, compressibility, and thermal expansion.
#
# * **Energy balance in metabolism**
# – Gibbs and Helmholtz free energies help describe ATP hydrolysis and energy transfer in biochemical pathways.
#
# * **Protein folding / binding**
# – Free energy landscapes determine stability of folded proteins, ligand–receptor interactions, and drug binding affinities.
#
# * **Respiration & oxygen transport**
# – Gibbs free energy of redox reactions (O₂/H₂O) explains energy yield in mitochondria.
#
# * **Osmosis and membrane transport**
# – Chemical potentials govern diffusion, osmosis, and ion exchange in cells.
#
# * **Thermodynamic response functions**
# – Maxwell relations connect entropy and volume changes to experimentally measurable properties (e.g., how lung tissue expands with temperature or pressure changes).
#
# * **Medical devices**
# – Thermodynamic potentials are applied in MRI cooling systems, cryopreservation, and inhalation anesthetics (linking pressure, entropy, and temperature).
#
#
# # 1. Theory
#
# ## 1.1. Thermodynamic Potentials
#
# Thermodynamic potentials are scalar quantities that provide useful ways to describe the state of a thermodynamic system. These potentials are functions of different natural variables and can be used to derive important relationships between thermodynamic properties. The four primary thermodynamic potentials are:
#
#    - **Internal Energy** ($U = U(S, V)$)
#    - **Enthalpy** ($H(S, P) = U + PV$)
#    - **Helmholtz Free Energy** ($F(T, V) = U - TS$)
#    - **Gibbs Free Energy** ($G(T, P) = H - TS$)
#
# Each thermodynamic potential has a specific set of **natural variables**, which are the variables that it is most conveniently expressed in terms of:
#
# | Potential | Natural Variables | Spontaneity condition | Equilibrium conditions | Physical meaning (Importance) |
# |  ---      | ---               | ---                   | ---                    | ---     |
# | U         | S, V              | dU < 0                |  dU = 0, d2U > 0       | The total energy contained within a system |
# | H         | S, P              | dH < 0                |  dH = 0, d2H > 0       | The total heat content of a system that can be released under constant pressure |
# | F         | T, V              | dF < 0                |  dF = 0, d2F > 0       | Work obtainable from a closed system at constant temperature. |
# | G         | T, P              | dG < 0                |  dG = 0, d2G > 0       | The maximum reversible work obtainable from a closed system at constant temperature and pressure. |
#
# ## 1.2. Fundamental equations of Thermodynamics.
#
# $dU = TdS − PdV$
#
# $dH = TdS + VdP$
#
# $dF = −SdT − PdV$
#
# $dG = −SdT + VdP$
#
# As a consequence:
#
# 1. From the Internal energy:
#
# $(\frac{\partial U}{\partial S})_V = T$
#
# $(\frac{\partial U}{\partial V})_S = -P$
#
# 2. From the enthalpy:
#
# $(\frac{\partial H}{\partial S})_P = T$
#
# $(\frac{\partial H}{\partial P})_S = V$
#
# 3. From the Helmholtz free energy:
#
# $(\frac{\partial F}{\partial T})_V = -S$
#
# $(\frac{\partial F}{\partial V})_T = -P$
#
# 4. From the Gibbs free energy:
#
# $(\frac{\partial G}{\partial T})_P = -S$
#
# $(\frac{\partial G}{\partial P})_T = V$
#
#
# ## 1.3. Maxwell's Relations
#
# Maxwell's relations are a set of equations derived from the second derivatives of thermodynamic potentials. They provide a connection between different thermodynamic quantities and are very useful in solving problems in thermodynamics.
#
# These relations arise from the fact that the mixed second derivatives of a state function are equal. For example, for a function $f(x,y)$, we have:
# $ \frac{\partial^2f}{\partial x \partial y} = \frac{\partial^2f}{\partial y \partial x} $
#
# Applying this idea to the thermodynamic potentials, we obtain the Maxwell relations:
#
# 1. From the Internal Energy $U(S,V)$:
#
# $(\frac{ \partial T}{\partial V})_S = -(\frac{ \partial P}{\partial S})_V$
#
# 2. From the Enthalpy $H(S,P)$:
#
# $(\frac{ \partial T}{\partial P})_S = (\frac{ \partial V}{\partial S})_P$
#
# 3. From the Helmholtz Free Energy $F(T,V)$:
#
# $(\frac{ \partial S}{\partial V})_T = (\frac{ \partial P}{\partial T})_V$
#
# 4. From the Gibbs Free Energy $G(T,P)$:
#
# $(\frac{ \partial S}{\partial P})_T = -(\frac{ \partial V}{\partial T})_P$
#
#
# ## 1.4. Gibbs-Helmholtz equations
#
# $(\frac{\partial (F/T)}{\partial T})_V = -\frac{U}{T^2}$
#
# $(\frac{\partial (G/T)}{\partial T})_P = -\frac{H}{T^2}$

# %% [markdown]
# # 2. Examples

# %% [markdown]
# ## Problem 1. [Eremin Example 5-1]
#
# Internal energy of a system is given as a function of its entropy and volume, $U(S,V)$. Compute themperature and heat capacity of this system.
#
# ### Solution

# %% [markdown]
# From the equation $dU = TdS − PdV$ we obtain directly:
#
# $(\frac{\partial U}{\partial S})_V = T$
#
# The heat capacity is:
#
# $C_{V} = (\frac{\partial U}{\partial T})_V$
#
# Using the chain rule, we then find:
#
# $C_{V} = (\frac{\partial U}{\partial T})_V = (\frac{\partial U}{\partial S})_V  (\frac{\partial S}{\partial T})_V$
#
# We can also use the property:
#
# $(\frac{\partial S}{\partial T})_V  =  ((\frac{\partial T}{\partial S})_V )^{-1} $
#
# Using Maxwell's equations:
#
# $(\frac{\partial U}{\partial S})_V = T$
#
# and
#
# $(\frac{\partial S}{\partial T})_V  =  ((\frac{\partial T}{\partial S})_V )^{-1} = ((\frac{\partial^2 U}{\partial S^2})_V )^{-1}   $
#
# $C_{V} = (\frac{\partial U}{\partial S})_V  (\frac{\partial S}{\partial T})_V = T ((\frac{\partial^2 U}{\partial S^2})_V )^{-1} =  (\frac{\partial U}{\partial S})_V  ((\frac{\partial^2 U}{\partial S^2})_V )^{-1} $

# %% [markdown]
# ## Problem 2. [Eremin Example 5-2]
#
# Using the fundamental equations of thermodynamics, find the dependence of enthalpy on pressure at constant temperature: a) for an arbitrary system; b) for the ideal gas.
#
# ### Solution

# %% [markdown]
# Note that we can not uses the equation
#
# $(\frac{\partial H}{\partial P})_S = V$
#
# directly, because it works only for the constant entropy case (e.g. adiabatic process)
#
# Instead, we start from the fundamental equation: $dH = TdS + VdP$
#
# Divide both sides by $dP$ and applying the constant temperature condition to the resulting derivatives, we obtain:
#
# $(\frac{\partial H}{\partial P})_T = T (\frac{\partial S}{\partial P})_T + V$
#
# using one of the Maxwell's equations, the right-hand side becomes:
#
# $(\frac{\partial H}{\partial P})_T = T (\frac{\partial S}{\partial P})_T + V = - T (\frac{\partial V}{\partial T})_P + V $
#
# a) so in general case:
#
# $(\frac{\partial H}{\partial P})_T = - T (\frac{\partial V}{\partial T})_P + V $
#
# b) for the ideal gas we have: $V = \frac{n R T}{P}$, so:
#
# $(\frac{\partial V}{\partial T})_P = \frac{n R}{P}$
#
# $T (\frac{\partial V}{\partial T})_P = \frac{n R T}{P} = V$
#
# $(\frac{\partial H}{\partial P})_T = - T (\frac{\partial V}{\partial T})_P + V = -V + V = 0$

# %% [markdown]
# ## Problem 3.
#
# Using the fundamental equations of thermodynamics, prove the Gibbs-Helmholtz equations
#
# ### Solution
#
# For instance, we want to prove:
#
# $(\frac{\partial (F/T)}{\partial T})_V = -\frac{U}{T^2}$
#
# Using the rules of differentiation of a fraction, we get:
#
# $\frac{  (\frac{\partial F}{\partial T})_V T - F }{T^2} $
#
# Using one of the Maxwell's equation, we get:
#
# $\frac{  -S T - F }{T^2} $
#
# Using the definition of $F = U - TS$, we get:
#
# $\frac{  -S T - U + TS }{T^2} = - \frac{- U }{T^2}$

# %% [markdown]
# ## Problem 4
#
# (5 points max) Compute $\Delta G$ for the process of a gas compression from 1 atm to 3 atm at 298 K: a) for one mole of liquid water; b) one mole of water vapor (ideal gas). Hint: recall that density of water is 1 g/mL.
#
# ### Solution
#
# For the liquid we use the formula:
#
# $\Delta G_m = V_m \Delta P $
#
# For the gaseous water (vapor), we use the formula:
#
# $\Delta G_m = R T ln(\frac{P_2}{P_1})$
#
# The actual $\Delta G$ is found from the $\Delta G_m$ by:
#
# $\Delta G = n \Delta G_m$

# %%
import math 

n = 1.0 # moles
R = 8.314 # J/mol*K
T = 298.0 # K
atm2Pa = 101325.0 #  P[Pa] = P[atm] * atm2Pa

P1 = 1.0 * atm2Pa # Pa
P2 = 3.0 * atm2Pa # Pa

# For the liquid case, we need to know the molar volume
# 1 mol of water is 18.0 g
# using density, we find that the volume of 18.0 grams of water is 18.0 mL

V_m = 18.0 # mL = cm^3
V_m = V_m * 1e-6 # m^3

dG_liq = n * V_m * (P2 - P1)


print(F" dG_liquid = {dG_liq} J")


# For gas, we obtain:
dG_gas = n * R * T * math.log(P2/P1)

print(F" dG_gas = {dG_gas} J")
# Out:
#  dG_liquid = 3.6477 J
#  dG_gas = 2721.891045260026 J

# %% [markdown]
# ## Problem 5
#
# (5 points max) Compute $\Delta U, \Delta H, \Delta S, \Delta G, \Delta F$ for a process of adiabatic expansion of 1 L of $O_2$ (t=25℃, $P_1$=5 atm) to $P_2$=1 atm. $C_{p,298}=29.38 \frac{J}{mol K}$ and $S_{298}^{\theta}=205.04 \frac{J}{mol K}$. Also determine the final values of V and T in this process.
#
# ### Solution
#
# As in the previous HW, we need to use a different form of the adiabat equation.
#
# In class, we considered $T V^{\gamma-1} = const$
#
# but also we have the ideal gas EOS $PV = nRT$, so:
#
# $\frac{PV}{nR} V^{\gamma-1} = const$
#
# or $PV^{\gamma} = const$
#
# Here, $\gamma = \frac{Cp}{Cv}$

# %%
atm2Pa = 101325.0 #  P[Pa] = P[atm] * atm2Pa

T1 = 25 + 273.15 # K
P1 = 5 * atm2Pa # Pa
P2 = 1 * atm2Pa # Pa
Cp = 29.38 # J/mol*K
R = 8.314 # J/mol*K
V1 = 1.0 * 1e-3 # m^3
S = 205.04 # J/mol*K

# From the ideal gas law, let's compute the number of moles of the gas:
n = (P1 * V1)/(R*T1)

print(F"moles = {n}")

# For ideal gas: Cp - Cv = R, so
Cv = Cp - R
gamma = Cp/Cv

# From the equation of adiabat, we find the final volume:
# P1/P2 = (V2/V1)^gamma
V2 = V1 * math.pow( P1/P2, 1.0/gamma )

print(F"final volume = {V2} m^3 = {V2 * 1000.0} L")

# Determine the final temperature - from the ideal gas law:
T2 = P2 * V2/(n*R)

print(F"final temperature = {T2} K")

# Now, let's determine the changes of thermodynamic functions:
dU = n * Cv * (T2 - T1)
dH = n * Cp * (T2 - T1)

# Because the process is adiabatic (isoentropic), dS = 0.0
dS = 0.0

# G = H - T S => dG = dH - TdS - SdT, for molar properties
# for the full changes, need to account for the number of moles
dT = T2 - T1
dG = dH - n*(T*dS  - S*dT)

# F = U - TS => dF = dU - TdS - SdT, for molar properties
# for the full changes, need to account for the number of moles
dF = dU - n*(T*dS - S*dT)


print(F"dU = {dU} J")
print(F"dH = {dH} J")
print(F"dF = {dF} J")
print(F"dG = {dG} J")
# Out:
# moles = 0.20438159444551643
# final volume = 0.0031708400869724933 m^3 = 3.1708400869724933 L
# final temperature = 189.07719438616977 K
# dU = -469.61325564086235 J
# dH = -654.9528838283745 J
# dF = -5040.462108607843 J
# dG = -5225.801736795356 J

# %% [markdown]
# # 3. Problems

# %% [markdown]
# ## 3.1. [Eremin Example 5-3]
#
# Express the derivatives $(\frac{\partial S}{\partial U})_V$ and $(\frac{\partial S}{\partial V})_U$ via other thermodynamic parameters

# %% [markdown]
# ## 3.2. [Eremin Example 5-4]
#
# Two moles of helium are heated from 100 to 200 Celsius under pressure of p = 1 atm. Assuming He behaves as an ideal gas, compute the change of Gibbs' free energy in this process. It is known that $S_{373}^{\theta} = 131.7$ J/(mol*K).

# %% [markdown]
# ## 3.3. [Eremin 5-17]
#
# One mole of a van-der-Waals gas expands isothermally from volume $V_1$ to volume $V_2$.
#
# Compute: a) $\Delta U$; b) $\Delta H$; c) $\Delta S$; d) $\Delta F$; e) $\Delta G$

# %% [markdown]
# ## 3.4. [Eremin 5-18]
#
# Compute $\Delta H$, $\Delta U$, $\Delta F$, $\Delta G$ and $\Delta S$ under simultaneous cooling and expanding 0.7 moles of nitrogen gas. The initial and final temperatures are $T_1 = 2000\ K$, $T_2 = 200\ K$ and volumes are $V_1 = 0.5\ m^3$, $V_2 = 1.35 m^{3}$. The entropy of gas in its initial state is $S_i = 150 J\cdot K\cdot mol^{-1}$. Assume the gas to be an ideal gas.

# %% [markdown]
# # 4. Answers
#
# ## 4.1.
#
# ## 4.2.
# $\Delta G = -26850\ J$
#
# ## 4.3.
# $$
# \Delta U = \frac{a}{V_1} - \frac{a}{V_2} \\
# \Delta H = R\ T\ b ( \frac{1}{V_2 - b} - \frac{1}{V_1 - b}) - 2\ a\ (\frac{1}{V_2} - \frac{1}{V_1}) \\
# \Delta S = R \ln (\frac{V_2 - b}{V_1 - b})
# $$
# The rest follows
#
# ## 4.4.
# $\Delta H = -36.65 kJ$, $\Delta U = -26.18 kJ$, $\Delta F = 249.4 kJ$, $\Delta G = 238.9 kJ$, $\Delta S = -27.71 J\cdot K^{-1}$
